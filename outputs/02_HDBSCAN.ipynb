# %% [markdown]
# ## Text Clustering and Labeling Utilizing OpenAI API

# %%
import os
import openai
from dotenv import load_dotenv, find_dotenv
import hdbscan
import numpy as np
import pandas as pd
import polars as pl
import plotly.express as px
import requests
from openai import OpenAI
from umap import UMAP
import tiktoken
import sys
from pathlib import Path
from tqdm import tqdm
import sklearn
import ast
client = OpenAI()

# %%
# Load the environment variables from the .env file
load_dotenv(find_dotenv(), override=True)

# Get the API key
openai.api_key = os.getenv('OPENAI_API_KEY')

# Verify if the API key is set correctly
if openai.api_key:
    print("OpenAI API key is loaded successfully.")
else:
    print("Error: OpenAI API key is not found. Check your .env file.")
# Out:
# OpenAI API key is loaded successfully.

# %%
embedding_model = "text-embedding-3-large"
embedding_encoding = "cl100k_base"
max_tokens = 8000

# %%
current_directory = Path.cwd()
parent_dir = current_directory.parent

# %%
file_path = f'{parent_dir}/outputs/data/categorical'
PCS_df = pd.read_csv(f'{file_path}/Patient Characteristics Survey (Years 2013 - 2022) (categorical).csv')

sample_size = 10000
sample_PCS_df = PCS_df.sample(n=sample_size, random_state=42)

# %%
# 1. Stack the DataFrame (removes empty cells automatically)
stacked = sample_PCS_df.stack()

# 2. Get headers and values, enforcing string types for safety
# .astype(str) on the index handles cases where a column name might be NaN or an integer
headers = stacked.index.get_level_values(1).astype(str)
values = stacked.astype(str).str.strip()

# 3. Create the formatted string "Column: Value"
formatted_values = headers + ": " + values

# 4. Group by the original row index (level=0) and join
# We add .dropna() before grouping to ensure no stray NaNs break the join
sample_PCS_df['intake'] = formatted_values.dropna().groupby(level=0).agg('; '.join)

# 5. Fill any rows that had zero data with an empty string
sample_PCS_df['intake'] = sample_PCS_df['intake'].fillna("")

# %%
encoding = tiktoken.get_encoding(embedding_encoding)

sample_PCS_df["n_tokens"] = sample_PCS_df.intake.apply(lambda x: len(encoding.encode(x)))

# %% [markdown]
# #### Get embeddings and save them for future reuse

# %%
os.makedirs('embeddings', exist_ok=True)

# %%
from tenacity import retry, stop_after_attempt, wait_random_exponential

@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(10))
def get_embeddings_batch(texts, model=embedding_model):
    clean = [str(t).replace("\n", " ") for t in texts]
    response = client.embeddings.create(input=clean, model=model)
    return [d.embedding for d in response.data]

batch_size = 100
all_embeddings = []
for i in tqdm(range(0, len(sample_PCS_df), batch_size), desc="Embedding batches"):
    batch = sample_PCS_df['intake'].iloc[i:i+batch_size].tolist()
    all_embeddings.extend(get_embeddings_batch(batch))

embeddings = np.vstack(all_embeddings)

file_path = f'{parent_dir}/outputs/embeddings'
os.makedirs(file_path, exist_ok=True)
np.save(f'{file_path}/embeddings.npy', embeddings)
# Out:
# Embedding batches: 100%|██████████| 100/100 [03:42<00:00,  2.22s/it]

# %%
# embeddings = np.load(f'{parent_dir}/outputs/embeddings/embeddings.npy')

# %%
hdb = hdbscan.HDBSCAN(min_cluster_size=100, min_samples=10).fit(embeddings)
sample_PCS_df["cluster"] = hdb.labels_.astype(str)

# %%
# Reduce dimensionality with UMAP
umap = UMAP(n_components=2, random_state=42, n_neighbors=80, min_dist=0.1)
df_umap = (pd.DataFrame(umap.fit_transform(np.array(embeddings)), columns=["x", "y"])
           .assign(cluster=hdb.labels_.astype(str))
           .query("cluster != '-1'")
           .sort_values(by="cluster"))

# Visualize clusters
fig = px.scatter(df_umap, x="x", y="y", color="cluster", title="UMAP Clusters")
fig.show()
# Out:
# /Users/alexanderperalta/anaconda3/envs/healthcare_project/lib/python3.14/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
print(f"Noise points: {(hdb.labels_ == -1).sum()}")
print(f"Clustered points: {(hdb.labels_ != -1).sum()}")
# Out:
# Noise points: 1605
# Clustered points: 8395

# %%
def generate_cluster_text(df, output_col, system_message, user_template, text_col="intake"):
    df[output_col] = "Pending"
    
    for c in tqdm(df["cluster"].unique(), desc=f"Generating {output_col}"):
        if c == '-1':
            continue
            
        cluster_data = df[df["cluster"] == c][text_col].tolist()
        if not cluster_data:
            continue
        
        # Sample if cluster is large to stay within context window
        if len(cluster_data) > 20:
            cluster_data = cluster_data[:20]
        
        data_str = "\n\n".join(f"{i+1}. {entry}" for i, entry in enumerate(cluster_data))
        
        try:
            response = client.chat.completions.create(
                model="gpt-4o-mini",
                messages=[{"role": "system", "content": system_message},
                          {"role": "user", "content": user_template.format(data_str)},],
                temperature=0.7, seed=42,)
            df.loc[df["cluster"] == c, output_col] = response.choices[0].message.content.strip()
        except Exception as e:
            print(f"Error for cluster {c}: {e}")
            df.loc[df["cluster"] == c, output_col] = "Error"

# Generate topic titles
generate_cluster_text(sample_PCS_df,
                      output_col="cluster_name",
                      system_message="You are an expert health economist analyzing the New York Patient Characteristics Survey.",
                      user_template="Based on the following patient intake data, write a short descriptive title (5-10 words) that captures the defining characteristics of this patient group.\n\nDATA:\n\n{}\n\nTOPIC TITLE:")

# Generate clinical notes
generate_cluster_text(sample_PCS_df,
                      output_col="cluster_notes",
                      system_message="You are an expert health economist tasked with writing clinical notes summarizing patient characteristics.",
                      user_template="Write a concise clinical summary (one paragraph) of the key characteristics and health statuses of the patients in this cluster.\n\nDATA:\n\n{}\n\nCLINICAL NOTES:")
# Out:
# Generating cluster_name: 100%|██████████| 12/12 [00:40<00:00,  3.38s/it]
# Generating cluster_notes: 100%|██████████| 12/12 [01:29<00:00,  7.46s/it]

# %%
clusters = sorted(list(sample_PCS_df['cluster'].unique()))

for c in clusters:
    with pd.option_context("display.max_colwidth", None):
        cluster_rows = sample_PCS_df.query(f"cluster == '{c}'")
        if not cluster_rows.empty:
            print(f"Topic Title for Cluster {c}: {cluster_rows.cluster_name.values[0]}")
            print(f"Clinical Notes: {cluster_rows.cluster_notes.values[0]}")
            print(f"Size: {len(cluster_rows)} patients")
        else:
            print(f"No data found for cluster {c}")
# Out:
# Topic Title for Cluster -1: Pending
# Clinical Notes: Pending
# Size: 1605 patients
# Topic Title for Cluster 0: "Unemployed Adults with Mental Illness and Substance Use"
# Clinical Notes: The patient cluster primarily consists of adults from the Western Region, with a mix of male and female individuals, predominantly identifying as heterosexual, and primarily of White or Black race. Most patients are unemployed and not looking for work, with various education levels ranging from middle school to college. Mental illness is a common diagnosis among this group, often accompanied by substance-related disorders; serious mental illness is noted in several cases. Many patients live alone or in private residences, and a significant number report issues with smoking. The insurance status varies, with some individuals lacking any form of insurance, while others are covered by Medicaid and Medicare. Notably, many of these patients have criminal justice involvement. Chronic health conditions are inconsistently reported, with some patients expressing unknown statuses for common conditions like hypertension, diabetes, and obesity. Overall, this cluster reflects the complex interplay of mental health issues, substance use disorders, and socio-economic challenges within a vulnerable population.
# Size: 329 patients
# Topic Title for Cluster 1: "Unemployed Adult Males with Mental Health Issues"
# Clinical Notes: This patient cluster consists predominantly of adult males (approximately 65% of the cohort), with a mix of racial and ethnic backgrounds, including Hispanic and Black individuals, primarily residing in the Central New York region. Many patients are unemployed and not actively seeking work, with a significant portion living in various arrangements such as private residences or other living situations. The educational attainment varies, with most participants having completed middle school to high school. A notable prevalence of mental illness is observed across the cluster, with serious mental illness reported in nearly all cases, often accompanied by substance-related disorders. Chronic medical conditions vary, with some patients reporting diabetes, obesity, and hypertension, while others have undetermined chronic conditions or none at all. Insurance coverage is also inconsistent, with a significant number of patients lacking any form of health insurance, which further complicates their access to necessary healthcare services. The criminal justice involvement is a common factor among this group, indicating potential social and environmental challenges impacting their overall health and well-being.
# Size: 149 patients
# Topic Title for Cluster 10: "Outpatient Male Patients with Mental Illness in Hudson River"
# Clinical Notes: The patient cluster primarily consists of adult males from the Hudson River Region, with a notable representation of children as well. The adults generally range from middle school to college education levels, displaying high prevalence rates of mental illness, particularly serious mental illness, across the cluster. Many are unemployed and not actively seeking work, with varying living situations, including cohabitation and living alone. Notably, the patient group shows significant comorbidity with high blood pressure and obesity, alongside other chronic conditions such as hyperlipidemia. Insurance coverage is predominantly through Medicaid, with some individuals receiving SSI and SSDI assistance. The children in the group display similar mental health issues and often have a household composition indicating cohabitation. The overall lack of formal education, along with high unemployment rates, suggests a need for targeted interventions focused on both mental health services and vocational support.
# Size: 283 patients
# Topic Title for Cluster 2: "Unemployed Hispanic and Black Males with Mental Illness"
# Clinical Notes: The patient cluster comprises adult males primarily from the Hudson River Region, predominantly identifying as heterosexual, with a varied ethnic background including Hispanic and Black individuals, as well as some identifying as White. A significant number of these patients report being unemployed and not actively seeking work, with education levels ranging from middle school to college or graduate degrees. Mental illness is a common concern among this group, with many patients diagnosed with serious mental illness, including conditions related to substance use. Various additional health issues were noted, including endocrine conditions and diabetes in some cases, while others reported pulmonary asthma. A considerable portion of patients is uninsured or reliant on Medicaid, with some receiving public assistance. Criminal justice involvement is present in several cases. Smoking is a noted behavior among many patients, indicating a potential area for intervention. Overall, the cluster reflects a complex interplay of mental health, socioeconomic factors, and varying degrees of health status.
# Size: 218 patients
# Topic Title for Cluster 3: "Unemployed Women with Mental Illness in Hudson River Region"
# Clinical Notes: The patient cluster consists predominantly of adult females from the Hudson River Region, primarily identifying as heterosexual and of either White or Black race. A significant number of patients report mental illness, with many also experiencing serious mental illness and co-occurring disorders, including substance-related issues. Employment status varies; some patients are unemployed and not seeking work, while others are employed part-time. The majority live alone or with others in private residences, with a few in other living situations. Educational backgrounds range from middle school to college graduates. Health issues are common, particularly high blood pressure, pulmonary asthma, and, in some cases, obesity and joint disease. Many patients lack health insurance, although some are covered by Medicaid and Medicare. A notable proportion has criminal justice involvement, indicating a potential need for integrated support services. Overall, this cluster reflects a vulnerable population requiring comprehensive mental health and social support interventions.
# Size: 114 patients
# Topic Title for Cluster 4: "Unemployed Adults with Serious Mental Illness in Long Island"
# Clinical Notes: The patient cluster consists of predominantly adult individuals residing in the Long Island Region, primarily of White ethnicity, with a mix of both male and female patients. The majority live in private residences, with some cohabitating with others and others living alone. The educational background varies from middle school to college-level degrees. A significant portion of the patients is unemployed and not actively seeking work, with some receiving SSDI cash assistance. Mental illness is a common diagnosis within this group, with serious mental illness noted in several cases; many patients also have co-occurring substance use disorders. Chronic health conditions such as high blood pressure, obesity, and hyperlipidemia are prevalent among certain individuals, while others report no chronic medical conditions. Smoking is noted as a behavior in multiple cases, with some patients not receiving smoking cessation support. Most patients have Medicaid and Medicare insurance coverage, ensuring access to healthcare services. Overall, this cluster presents a complex interplay of mental health issues, socioeconomic challenges, and varying health statuses.
# Size: 190 patients
# Topic Title for Cluster 5: "Unemployed Adults with Serious Mental Illness in NYC"
# Clinical Notes: The patient cluster consists predominantly of adult males (65.5%) and females (34.5%) residing in the New York City region, primarily in private residences and living alone. The cohort is characterized by high unemployment rates, with most patients not in the labor force and not actively seeking work; a significant portion holds college or graduate degrees. Mental illness is prevalent among all individuals, with serious mental illness reported, and many patients also exhibit co-occurring substance-related disorders. Notably, a segment of patients has additional health challenges including obesity, diabetes, and pulmonary asthma. The insurance coverage is varied, with a mix of Medicaid and Medicare, while some individuals lack comprehensive insurance. There is also a notable presence of patients with criminal justice involvement, indicating a potential need for integrated care approaches. Overall, this patient population demonstrates significant mental health needs, often compounded by socioeconomic challenges and various health comorbidities.
# Size: 1115 patients
# Topic Title for Cluster 6: "Central NY Outpatient Adults with Serious Mental Illness"
# Clinical Notes: The patient cluster consists of both male and female adults, with a minority of children, predominantly residing in the Central NY Region. Many of the adult patients are unemployed and not seeking work, with varying education levels primarily ranging from middle school to college graduates. Mental illness is a common characteristic, with serious mental illness reported among most individuals; several patients also exhibit additional developmental disabilities. Substance use disorders, primarily alcohol and drug-related, are present, alongside physical health issues such as obesity, diabetes, and hypertension in some cases. Living situations predominantly indicate private residences with either cohabitation or living alone. Health insurance coverage mainly includes Medicaid, with some patients also holding Medicare, while others rely on public assistance. Notably, smoking is a reported behavior among several patients, and many have received smoking counseling, though few have engaged in smoking cessation programs. Overall, this population demonstrates significant health and social challenges, necessitating comprehensive outpatient services.
# Size: 650 patients
# Topic Title for Cluster 7: "Outpatient Adult Mental Health Patients in Western NY"
# Clinical Notes: The patient cluster primarily consists of adults and children receiving outpatient services in the Western Region, with a notable predominance of female patients (53%) compared to males (47%). The demographic profile reveals a diverse racial composition, including Black, White, and Other races, with a significant proportion identifying as Hispanic/Latino among males. Most patients report living in private residences and cohabitating with others, reflecting varied household compositions. A commonality among this group is the presence of serious mental illness; all patients have been diagnosed with mental health disorders, with many exhibiting additional substance-related disorders. Employment status varies, with a significant number of patients being unemployed and not actively seeking work, while others are employed part-time or full-time. Educational backgrounds range from middle school to college degrees, and the majority of patients are enrolled in Medicaid, with some receiving additional public assistance. Notably, there is a high prevalence of smoking among some patients, with varying degrees of engagement in smoking cessation programs. Overall, this cluster highlights the complexities of mental health issues intertwined with socioeconomic factors, underscoring the need for comprehensive support services.
# Size: 1067 patients
# Topic Title for Cluster 8: "Outpatient Mental Health Patients in New York City"
# Clinical Notes: This patient cluster primarily consists of individuals from the New York City region, with a notable representation of both children and adults, predominantly female. The patients exhibit a high prevalence of mental illness, with many classified as having serious mental illness and a significant portion receiving special education services. Employment status reveals that most patients are unemployed and not actively seeking work, with various education levels primarily in the middle school to high school range. While chronic medical conditions are less common among the children, adults display a range of health issues including diabetes, hypertension, and obesity, alongside mental health challenges. Insurance coverage is largely through Medicaid, with many patients receiving public assistance. A considerable number of patients live in private residences, often cohabitating with others or living alone. The data reflects a diverse group in terms of race and ethnicity, with significant representation from Hispanic, Black, and White populations, indicating a need for tailored health services that address both mental and physical health needs within this community.
# Size: 3926 patients
# Topic Title for Cluster 9: "Outpatient Mental Health Patients in Hudson River Region"
# Clinical Notes: The cluster of patients primarily consists of adult and child females from the Hudson River Region, predominantly identifying as heterosexual, with a notable proportion identifying as bisexual. Most patients reside in private homes, often cohabitating with others. Employment status varies, with some individuals actively seeking work while others are unemployed and not looking. Educational backgrounds range from middle school to college, with several patients having received some college education. All patients exhibit mental illness, with many classified as having serious mental illness, and a mix of comorbidities including diabetes, obesity, pulmonary asthma, and joint disease. Most patients do not smoke, and insurance coverage is primarily through Medicaid, with some having Medicare or private insurance. The population is characterized by a lack of chronic medical conditions; however, many have significant mental health needs that necessitate ongoing support and treatment.
# Size: 354 patients

# %%
file_path = f'{parent_dir}/outputs/clusters'
os.makedirs(file_path)
sample_PCS_df.to_csv(f'{file_path}/clustered_patients.csv', index=False)
