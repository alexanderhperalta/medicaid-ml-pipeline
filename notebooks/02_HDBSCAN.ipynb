# %% [markdown]
# ## Text Clustering and Labeling Utilizing OpenAI API

# %%
import os
import openai
from dotenv import load_dotenv, find_dotenv
import hdbscan
import numpy as np
import pandas as pd
import polars as pl
import plotly.express as px
import requests
from openai import OpenAI
from umap import UMAP
import tiktoken
import sys
from pathlib import Path
from tqdm import tqdm
import sklearn
import ast

# %%
# Load the environment variables from the .env file
load_dotenv(find_dotenv(), override=True)
client = OpenAI()

# Get the API key
openai.api_key = os.getenv('OPENAI_API_KEY')

# Verify if the API key is set correctly
if openai.api_key:
    print("OpenAI API key is loaded successfully.")
else:
    print("Error: OpenAI API key is not found. Check your .env file.")
# Out:
# OpenAI API key is loaded successfully.

# %%
embedding_model = "text-embedding-3-large"
embedding_encoding = "cl100k_base"
max_tokens = 8000

# %%
current_directory = Path.cwd()
parent_dir = current_directory.parent

# %%
file_path = f'{parent_dir}/outputs/data/categorical'
PCS_df = pd.read_csv(f'{file_path}/Patient Characteristics Survey (Years 2013 - 2022) (categorical).csv')

sample_size = 10000
sample_PCS_df = PCS_df.sample(n=sample_size, random_state=42)

# %%
# 1. Stack the DataFrame (removes empty cells automatically)
stacked = sample_PCS_df.stack()

# 2. Get headers and values, enforcing string types for safety
# .astype(str) on the index handles cases where a column name might be NaN or an integer
headers = stacked.index.get_level_values(1).astype(str)
values = stacked.astype(str).str.strip()

# 3. Create the formatted string "Column: Value"
formatted_values = headers + ": " + values

# 4. Group by the original row index (level=0) and join
# We add .dropna() before grouping to ensure no stray NaNs break the join
sample_PCS_df['intake'] = formatted_values.dropna().groupby(level=0).agg('; '.join)

# 5. Fill any rows that had zero data with an empty string
sample_PCS_df['intake'] = sample_PCS_df['intake'].fillna("")

# %%
encoding = tiktoken.get_encoding(embedding_encoding)

sample_PCS_df["n_tokens"] = sample_PCS_df.intake.apply(lambda x: len(encoding.encode(x)))

# %% [markdown]
# #### Get embeddings and save them for future reuse

# %%
os.makedirs('embeddings', exist_ok=True)

# %%
from tenacity import retry, stop_after_attempt, wait_random_exponential

@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(10))
def get_embeddings_batch(texts, model=embedding_model):
    clean = [str(t).replace("\n", " ") for t in texts]
    response = client.embeddings.create(input=clean, model=model)
    return [d.embedding for d in response.data]

batch_size = 100
all_embeddings = []
for i in tqdm(range(0, len(sample_PCS_df), batch_size), desc="Embedding batches"):
    batch = sample_PCS_df['intake'].iloc[i:i+batch_size].tolist()
    all_embeddings.extend(get_embeddings_batch(batch))

embeddings = np.vstack(all_embeddings)

file_path = f'{parent_dir}/outputs/embeddings'
os.makedirs(file_path, exist_ok=True)
np.save(f'{file_path}/embeddings.npy', embeddings)
# Out:
# Embedding batches: 100%|██████████| 100/100 [03:42<00:00,  2.22s/it]

# %%
embeddings = np.load(f'{parent_dir}/outputs/embeddings/embeddings.npy')
sample_PCS_df = pd.read_csv(f'{parent_dir}/outputs/embeddings/embeddings.csv')

# %%
# Reduce for clustering
umap_cluster = UMAP(n_components=30, random_state=42, n_neighbors=80, min_dist=0.0, metric='cosine')
reduced = umap_cluster.fit_transform(embeddings)
# Out:
# /Users/alexanderperalta/anaconda3/envs/healthcare_project/lib/python3.14/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
from itertools import product

results = []
for mcs, ms, method in product([75, 100, 150, 200],
                               [5, 10, 20],
                               ['eom', 'leaf']):
    hdb = hdbscan.HDBSCAN(min_cluster_size=mcs, min_samples=ms,
                          cluster_selection_method=method,
                          gen_min_span_tree=True).fit(reduced)
    
    n_clusters = len(set(hdb.labels_)) - 1
    noise_pct = (hdb.labels_ == -1).mean()
    validity = hdb.relative_validity_
    
    results.append({'min_cluster_size': mcs, 'min_samples': ms,
                    'method': method, 'n_clusters': n_clusters,
                    'noise_pct': round(noise_pct, 3), 'dbcv': round(validity, 4)})

results_df = pd.DataFrame(results).sort_values('dbcv', ascending=False)
print(results_df.to_string(index=False))
# Out:
#  min_cluster_size  min_samples method  n_clusters  noise_pct   dbcv
#                75            5    eom          42      0.014 0.7480
#               100           20    eom          32      0.009 0.7367
#                75           10    eom          42      0.017 0.7268
#               150           20    eom          22      0.022 0.7265
#                75           20    eom          42      0.014 0.7191
#               100           10    eom          33      0.005 0.7117
#               200            5    eom          19      0.030 0.6764
#               200           10    eom          19      0.030 0.6731
#               100            5    eom          37      0.010 0.6681
#               200           20    eom          19      0.054 0.6673
#               150            5    eom          25      0.022 0.6404
#               150           10    eom          25      0.015 0.6395
#               150            5   leaf          33      0.040 0.4392
#               200           10   leaf          25      0.032 0.4159
#               100            5   leaf          46      0.107 0.4129
#               150           10   leaf          33      0.029 0.4105
#                75            5   leaf          65      0.114 0.4092
#               150           20   leaf          32      0.080 0.4078
#               200            5   leaf          26      0.046 0.4004
#               200           20   leaf          25      0.058 0.3920
#                75           20   leaf          64      0.114 0.3577
#               100           20   leaf          47      0.137 0.3534
#                75           10   leaf          64      0.123 0.3479
#               100           10   leaf          48      0.132 0.3449

# %%
# Pick the best row and use those params
# (replace these values with whatever scores highest)
hdb = hdbscan.HDBSCAN(min_cluster_size=250, min_samples=10,
                      cluster_selection_method='eom').fit(reduced)

sample_PCS_df["cluster"] = hdb.labels_.astype(str)

# %%
umap_viz = UMAP(n_components=2, random_state=42, n_neighbors=80, min_dist=0.1)
viz_coords = umap_viz.fit_transform(embeddings)


df_umap = (pd.DataFrame(viz_coords, columns=["x", "y"])
           .assign(cluster=hdb.labels_.astype(str))
           .query("cluster != '-1'")
           .sort_values(by="cluster"))

fig = px.scatter(df_umap, x="x", y="y", color="cluster", title="UMAP Clusters")
fig.show()
# Out:
# /Users/alexanderperalta/anaconda3/envs/healthcare_project/lib/python3.14/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
print(f"Noise points: {(hdb.labels_ == -1).sum()}")
print(f"Clustered points: {(hdb.labels_ != -1).sum()}")
# Out:
# Noise points: 46
# Clustered points: 9954

# %%
sample_PCS_df[sample_PCS_df["cluster"] != "-1"]["cluster"].value_counts().sort_values()
# Out:
# cluster
# 8      253
# 4      262
# 5      265
# 15     360
# 14     382
# 9      433
# 7      495
# 10     496
# 13     501
# 3      506
# 6      511
# 16     556
# 11     560
# 12     560
# 1      727
# 0     1148
# 2     1258
# Name: count, dtype: int64

# %%
drop_cols = ['Region Served',
             'Three Digit Residence Zip Code',
             'Survey Year',
             'intake',
             'n_tokens',
             'embedding',
             'cluster_name',
             'cluster_notes']

intake_df = sample_PCS_df.drop(columns=drop_cols)

# %%
# 1. Stack the DataFrame (removes empty cells automatically)
stacked = intake_df.stack()

# 2. Get headers and values, enforcing string types for safety
# .astype(str) on the index handles cases where a column name might be NaN or an integer
headers = stacked.index.get_level_values(1).astype(str)
values = stacked.astype(str).str.strip()

# 3. Create the formatted string "Column: Value"
formatted_values = headers + ": " + values

# 4. Group by the original row index (level=0) and join
# We add .dropna() before grouping to ensure no stray NaNs break the join
intake_df['intake'] = formatted_values.dropna().groupby(level=0).agg('; '.join)

# 5. Fill any rows that had zero data with an empty string
intake_df['intake'] = intake_df['intake'].fillna("")

# %%
import random

def generate_cluster_text(df, output_col, system_message, user_template, text_col="intake"):
    df[output_col] = "Pending"
    
    for c in tqdm(df["cluster"].unique(), desc=f"Generating {output_col}"):
        if c == '-1':
            continue
            
        cluster_data = df[df["cluster"] == c][text_col].tolist()
        if not cluster_data:
            continue
        
        cluster_size = len(cluster_data)
        
        if len(cluster_data) > 20:
            cluster_data = random.sample(cluster_data, 20)
        
        data_str = "\n\n".join(f"{i+1}. {entry}" for i, entry in enumerate(cluster_data))
        
        try:
            response = client.chat.completions.create(
                model="gpt-4o-mini",
                messages=[{"role": "system", "content": system_message},
                          {"role": "user", "content": user_template.format(cluster_size, data_str)},],
                temperature=0.7, seed=42,)
            df.loc[df["cluster"] == c, output_col] = response.choices[0].message.content.strip()
        except Exception as e:
            print(f"Error for cluster {c}: {e}")
            df.loc[df["cluster"] == c, output_col] = "Error"

# Generate topic titles
generate_cluster_text(intake_df,
                      output_col="cluster_name",
                      system_message="You are an expert health economist analyzing the New York Patient Characteristics Survey.",
                      user_template="Based on the following sample of patient intake data from a cluster of {} patients, write a short descriptive title (5-10 words) that captures the defining characteristics of this patient group.\n\nDATA:\n\n{}\n\nTOPIC TITLE:")

# Generate clinical notes
generate_cluster_text(intake_df,
                      output_col="cluster_notes",
                      system_message="You are an expert health economist tasked with writing clinical notes summarizing patient characteristics.",
                      user_template="Write a concise clinical summary (one paragraph) of the key characteristics and health statuses of the patients in this cluster of {} patients. Include what distinguishes this group from a general mental health population, and end with 1-2 sentences on the specific needs and recommended interventions for this population.\n\nDATA:\n\n{}\n\nCLINICAL NOTES:")
# Out:
# Generating cluster_name: 100%|██████████| 18/18 [00:42<00:00,  2.37s/it]
# Generating cluster_notes: 100%|██████████| 18/18 [01:39<00:00,  5.55s/it]

# %%
clusters = sorted(list(intake_df['cluster'].unique()))

for c in clusters:
    with pd.option_context("display.max_colwidth", None):
        cluster_rows = intake_df.query(f"cluster == '{c}'")
        if not cluster_rows.empty:
            print(f"Topic Title for Cluster {c}: {cluster_rows.cluster_name.values[0]}")
            print(f"Clinical Notes: {cluster_rows.cluster_notes.values[0]}")
            print(f"Size: {len(cluster_rows)} patients")
        else:
            print(f"No data found for cluster {c}")
# Out:
# Topic Title for Cluster -1: Pending
# Clinical Notes: Pending
# Size: 727 patients
# Topic Title for Cluster 0: "Unemployed Adults with Serious Mental Illness"
# Clinical Notes: This clinical summary encapsulates a diverse cohort of 1,148 patients primarily consisting of adult males (with some females and children) from various living situations, predominantly residing alone or cohabitating. Most patients are White, with a significant representation of individuals identifying as Hispanic/Latino, particularly among adults. A notable feature of this group is the high prevalence of serious mental illnesses, including substance-related disorders, with many patients also facing comorbid health conditions such as hypertension, diabetes, and mobility impairments. Compared to a general mental health population, this cluster is distinguished by a higher unemployment rate, a significant portion being out of the labor force and actively seeking work, alongside substantial engagement with public assistance programs. Interventions for this population should focus on integrated mental health and substance use treatment, alongside vocational rehabilitation services, to address both the psychological and economic challenges they face. Additionally, tailored health management for chronic conditions and smoking cessation support are crucial to enhance their overall well-being.
# Size: 1148 patients
# Topic Title for Cluster 1: "Adult Males with Serious Mental Illness and Disabilities"
# Clinical Notes: The cluster of 727 patients primarily consists of adult males, predominantly Black, with a notable representation of both Hispanic and other racial groups. The majority of these individuals are living in private residences or other living situations, often alone, and are largely unemployed and not actively seeking work, reflecting a significant barrier to economic stability. Most patients in this cohort experience serious mental illness, with a subset having co-occurring substance use disorders, particularly alcohol-related disorders. Common physical health issues include hypertension and, to a lesser extent, diabetes and obesity. This group is distinct from a general mental health population due to their high rates of unemployment, low educational attainment, and significant co-morbidity with substance use disorders, which exacerbate their mental health challenges. To address their specific needs, interventions should focus on integrated care models that combine mental health and substance use treatment with vocational rehabilitation services, alongside efforts to improve health literacy and access to community support resources.
# Size: 727 patients
# Topic Title for Cluster 10: "Characteristics of Female Patients with Serious Mental Illness"
# Clinical Notes: This cluster of 496 outpatient and inpatient patients is characterized predominantly by adult females, with a notable representation of both Hispanic and non-Hispanic individuals, mainly identifying as heterosexual. The majority live in private residences, often cohabitating with others, and exhibit a significant prevalence of serious mental illness, distinguishing them from the general mental health population where comorbidities and socioeconomic factors may vary more widely. Many patients are unemployed and not actively seeking work, with education levels ranging from middle school to college. Substance-related disorders, joint diseases, and obesity are prevalent among some, while others report a lack of chronic conditions, indicating a diverse range of healthcare needs. Specific interventions for this population should focus on integrated mental health services, tailored substance use treatment, and vocational rehabilitation programs to support employment readiness, while also addressing the social determinants of health that contribute to their mental health challenges.
# Size: 496 patients
# Topic Title for Cluster 11: "Female Adults with Serious Mental Illness and Diverse Health Needs"
# Clinical Notes: This clinical summary encompasses a cohort of 560 adult female patients, predominantly Black and White, with no reported Hispanic ethnicity, receiving outpatient mental health services. The majority of these patients are unemployed, with many not actively seeking work, and they exhibit a diversity of education levels ranging from middle school to graduate degrees. Most patients report serious mental illnesses, with significant co-morbidities such as diabetes, obesity, high blood pressure, and joint diseases, distinguishing this group from a general mental health population that tends to have a broader range of diagnoses and socio-economic stability. Additionally, a substantial number of these patients rely on Medicaid and public assistance, highlighting a need for targeted interventions that address both mental health and chronic physical health conditions, alongside employment support and lifestyle modifications to improve overall health outcomes. Recommended interventions include integrated care approaches that provide mental health treatment alongside chronic disease management, as well as employment counseling to facilitate job readiness and sustainable employment opportunities.
# Size: 560 patients
# Topic Title for Cluster 12: "Outpatient Adult Males with Mental Health Challenges"
# Clinical Notes: The cluster of 560 patients primarily consists of adult males, predominantly heterosexual, with a significant number identifying as Hispanic or Black, and a smaller subset as White or of other races. This group is characterized by a high prevalence of serious mental illness, predominantly classified under mental illness, with many patients also experiencing co-occurring issues such as alcohol-related disorders and mobility impairments. Unlike a general mental health population, this cohort exhibits a higher rate of unemployment, with most patients not actively seeking work and living alone or in other living situations, indicating potential social isolation. Furthermore, chronic medical conditions such as hypertension, diabetes, hyperlipidemia, and obesity are notable among this population, compounding their mental health challenges. Recommendations for this group include integrated care approaches that address both mental health and chronic physical health conditions, alongside focused interventions to enhance social support and vocational rehabilitation, to improve overall quality of life and health outcomes.
# Size: 560 patients
# Topic Title for Cluster 13: "Female Adults with Mental Illness and Unemployment"
# Clinical Notes: This cluster of 501 patients is characterized primarily by adult females, predominantly identifying as heterosexual, and largely comprising Black or Hispanic individuals, with a notable number living alone or cohabitating with others. A significant portion of this population exhibits serious mental illness, with a high prevalence of comorbid conditions, particularly substance use disorders, mobility impairments, and chronic health issues such as hypertension and diabetes. Unlike the general mental health population, this group shows a higher unemployment rate, with many not actively seeking work and lacking health insurance, which contributes to their socioeconomic vulnerability. Recommended interventions include comprehensive mental health treatment and substance use support, tailored health management plans addressing chronic conditions, and assistance with securing stable employment and health insurance coverage to enhance their overall well-being and integration into the community.
# Size: 501 patients
# Topic Title for Cluster 14: "Outpatient Mental Health Needs of Hispanic Female Children"
# Clinical Notes: The cluster of 382 outpatient child patients is predominantly female, aged between pre-K and high school, with a significant number identifying as Hispanic/Latino. Most patients are living in private residences, cohabitating with others, and are not currently in the labor force, indicating a lack of employment opportunities. A notable characteristic of this group is the presence of serious mental illnesses, with many patients facing challenges related to their mental health, yet lacking chronic physical health conditions. This cohort differs from the general mental health population by demonstrating a higher prevalence of severe mental illnesses without significant comorbid chronic health issues, suggesting a focused mental health intervention need. Recommended interventions include tailored outpatient therapy, psychoeducation for families, and coordination of mental health services to address the unique challenges faced by these children, particularly in the context of their cultural background and socioeconomic status.
# Size: 382 patients
# Topic Title for Cluster 15: "Outpatient Adult Males with Serious Mental Illness"
# Clinical Notes: The cluster of 360 outpatient adult male patients exhibits significant mental health challenges, with a predominant diagnosis of serious mental illness and a notable incidence of substance-related disorders among certain subgroups. This population is characterized by a higher prevalence of mobility impairments, high blood pressure, and hyperlipidemia, which distinguishes them from a general mental health population that may not share the same degree of chronic medical conditions. Furthermore, many patients fall within lower educational and employment categories, with a significant portion either unemployed or outside the labor force. Their social situations vary, but many live alone or cohabitate with others, and the majority prefer English as their primary language. Given these characteristics, there is a critical need for integrated care approaches that address both mental health and chronic physical conditions, alongside support for employment and social reintegration. Recommended interventions include comprehensive case management, access to physical health services, and targeted vocational training programs to enhance employment opportunities and improve overall quality of life.
# Size: 360 patients
# Topic Title for Cluster 16: "Children with Serious Mental Illness in Outpatient Care"
# Clinical Notes: The cluster of patients consists of 556 male children predominantly from Hispanic and Black backgrounds, with a significant portion living in private residences and cohabitating with others. Notably, all patients exhibit serious mental illnesses, which distinguishes them from a general mental health population that typically includes a broader spectrum of conditions and severity levels. Most patients are not actively seeking employment and have varied educational statuses, primarily falling between pre-K to high school levels, with many receiving special education services. A considerable number are covered by Medicaid, indicating potential socioeconomic challenges. This group also shows a high prevalence of serious mental illness while largely lacking chronic physical health conditions, which further separates them from the general patient demographic. To address their specific needs, it is recommended that interventions focus on enhancing access to mental health services, providing educational support, and fostering community engagement to improve their overall social integration and well-being.
# Size: 556 patients
# Topic Title for Cluster 2: "Outpatient Adult Males with Serious Mental Illness"
# Clinical Notes: The cluster comprises 1,258 patients primarily classified as adults, with a significant representation of children (notably among those with mental illnesses). The adult group is predominantly female (approximately 60%) and largely white, with a notable presence of Black individuals. Many patients have serious mental illnesses, with a significant proportion also experiencing comorbid substance use disorders, particularly among males. Unlike the general mental health population, this cluster exhibits a higher prevalence of unemployment or underemployment, with many patients reliant on public assistance programs, such as SSI and SSDI, indicating socioeconomic vulnerabilities. Specific needs for this population include integrated treatment approaches that address both mental health and substance use disorders, as well as enhanced access to vocational support services to improve employment outcomes. Tailored interventions such as cognitive-behavioral therapy, motivational interviewing, and chronic disease management for co-occurring conditions like diabetes and hypertension are recommended to better support their complex health profiles.
# Size: 1258 patients
# Topic Title for Cluster 3: "Adult Patients with Serious Mental Illness and Unemployment"
# Clinical Notes: The patient cluster consists of 506 individuals primarily composed of adult females (approximately 74%) and males (approximately 26%), with a notable presence of individuals identifying as Black or White and a small representation of other races. Most patients live alone or cohabitate, are unemployed and not actively seeking work, and have low educational attainment, typically ranging from middle school to high school. A significant proportion of this cohort suffers from serious mental illness, which distinguishes them from the general mental health population, where comorbidities are less prevalent. Chronic conditions such as hyperlipidemia, high blood pressure, and diabetes are also common among these patients, complicating their mental health treatment. Given the high prevalence of serious mental illness and chronic medical conditions, this group requires intensive support services, including integrated mental health and physical health care, as well as social support interventions to enhance their overall well-being and functionality. Additionally, addressing employment opportunities and educational programs tailored to their needs will be crucial for long-term recovery and stability.
# Size: 506 patients
# Topic Title for Cluster 4: "Outpatient Female Adults with Mental Health Challenges"
# Clinical Notes: This clinical summary encompasses a cluster of 262 female adult patients receiving outpatient mental health services, predominantly characterized by significant mental illness and a high prevalence of socioeconomic challenges. A notable distinction from the general mental health population is the high rate of unemployment, with many patients not actively seeking work, and a substantial reliance on public assistance programs. The group is diverse in racial and ethnic backgrounds, with a significant representation of Hispanic/Latino individuals and varying preferred languages, primarily English and Spanish. Common health concerns among this cohort include serious mental illness, high blood pressure, diabetes, and mobility impairments, further complicated by lifestyle factors such as smoking. Given these complexities, this population requires targeted interventions, including culturally competent mental health services, vocational support programs to facilitate employment, and comprehensive management for chronic health conditions to improve overall quality of life and enhance social integration.
# Size: 262 patients
# Topic Title for Cluster 5: "Adults with Serious Mental Illness and Unemployment"
# Clinical Notes: The cluster of 265 patients is predominantly composed of adult males (majority White, with a significant representation of Black individuals) who are experiencing serious mental illness, specifically classified under mental illness and substance-related disorders. Key distinguishing features of this group compared to a general mental health population include high unemployment rates, a significant proportion receiving SSI cash assistance, and a lack of stable employment engagement, with most patients not actively seeking work. Additionally, many patients report smoking and have limited access to preventive health measures, such as smoking cessation counseling. This population has specific needs for integrated treatment approaches that address both mental health and substance use disorders, as well as vocational support and smoking cessation programs to enhance their quality of life and promote recovery. Recommended interventions should include comprehensive case management, tailored substance use treatment, and targeted employment support services to facilitate reintegration into the workforce.
# Size: 265 patients
# Topic Title for Cluster 6: "Outpatient Mental Health Patients: Diverse Demographics"
# Clinical Notes: The cluster of patients (n=511) primarily consists of adults, with a significant representation of both genders, predominantly White, and non-Hispanic, living in private residences, often alone or cohabitating with others. A notable characteristic of this group is the high prevalence of serious mental illness, with many patients also facing additional challenges related to substance use disorders—particularly among males. This group is distinguished from the general mental health population by its higher rates of unemployment and lower educational attainment, coupled with a reliance on public insurance programs such as Medicaid and Medicare. There is also a significant presence of chronic health conditions, especially among those with substance-related issues. Recommended interventions for this population include integrated treatment approaches that address both mental health and substance use disorders, along with social support services to enhance employment opportunities and educational access, especially for those facing additional health-related barriers.
# Size: 511 patients
# Topic Title for Cluster 7: "Outpatient Adult Male Patients with Mental Illness"
# Clinical Notes: This cluster of 495 patients, primarily adult males, displays a distinctive profile characterized by a high prevalence of serious mental illness, significant intellectual disabilities, and autism spectrum disorders, setting them apart from a general mental health population. The cohort includes a mix of Hispanic and non-Hispanic individuals, with varying educational backgrounds, the majority falling within middle and high school education levels. Notably, many are unemployed and seeking work, with a significant portion relying on Medicaid and Medicare for insurance coverage. While they generally do not present with chronic physical health conditions, the presence of developmental disabilities and serious mental health issues underscores their complex care needs. Recommended interventions for this population include tailored mental health services emphasizing developmental and social skills training, as well as vocational rehabilitation support to facilitate employment opportunities, alongside integrated care approaches to address their multifaceted mental health and developmental challenges.
# Size: 495 patients
# Topic Title for Cluster 8: "Hispanic Female Adults with Serious Mental Illness"
# Clinical Notes: This cluster of 253 outpatient female patients primarily consists of adults who exhibit serious mental illness, predominantly categorized under mental illness diagnoses. The cohort is characterized by a significant proportion of individuals who are unemployed or not in the labor force, with many cohabitating with others in private residences. Notably, a substantial number identify as Hispanic/Latino, reflecting a diverse ethnic representation that distinguishes this group from the general mental health population, which may not have such a concentrated demographic. The patients present a range of additional health concerns, including mobility impairments and chronic conditions like high blood pressure and diabetes, further complicating their mental health management. Given their socioeconomic status, many of these patients rely on Medicaid for healthcare coverage, and a considerable portion receives public assistance. Recommended interventions for this population include integrated care strategies that address both mental health and physical health needs, culturally competent services tailored to their diverse backgrounds, and job readiness programs to enhance employment opportunities.
# Size: 253 patients
# Topic Title for Cluster 9: "Adult Patients with Serious Mental Illness and Unemployment"
# Clinical Notes: The cluster of 433 patients presents a unique population characterized predominantly by adults, with a significant number reporting serious mental illness and a high prevalence of substance use disorders, particularly alcohol and drug-related issues. The majority are unemployed and not actively seeking work, predominantly lacking higher education, and many reside in either residential settings or alone in private residences. This group also exhibits a notable presence of chronic conditions such as obesity, high blood pressure, and pulmonary asthma, which are less common in the general mental health population. Additionally, a significant portion of this cohort does not have access to private insurance, with many relying on Medicaid or being uninsured. The specific needs of this population include comprehensive mental health and substance use treatment, coupled with programs aimed at addressing physical health concerns and vocational training to enhance employability. Recommended interventions should focus on integrated care models that encompass mental health services, substance use counseling, and health education to promote overall well-being and recovery.
# Size: 433 patients
